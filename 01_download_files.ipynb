# %% [markdown]
# ## Download NetCDF files

# %%
# Import libraries
import os
import glob
import xarray as xr
from natsort import natsorted

# Import functions
from function_downloads import (
    download_netcdf_ereefs,
    download_netcdf_noaa,
    download_netcdf_csiro
)

# Inform your folder for the downloaded files
download_dir = "downloads"
os.makedirs(download_dir, exist_ok=True)

# %%
# Download eReefs files

download_netcdf_ereefs(
    base_url="https://thredds.ereefs.aims.gov.au/thredds/fileServer/ereefs/gbr1_2.0/daily-daily",
    download_dir=download_dir,
    start_year=2017, start_month=8, start_day=25,
    end_year=2017, end_month=8, end_day=26,
    file_prefix="EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-",
    date_format="%Y-%m-%d"
)
# Out:
# ============================================================
# eReefs NetCDF Downloader
# - Downloads NetCDF files from the AIMS eReefs THREDDS server
# - Supports daily or monthly files
# - Checks file existence before downloading
# ============================================================
#
# Checking: https://thredds.ereefs.aims.gov.au/thredds/fileServer/ereefs/gbr1_2.0/daily-daily/EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-25.nc
# Downloading: EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-25.nc
# Saved to: downloads\EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-25.nc
# Checking: https://thredds.ereefs.aims.gov.au/thredds/fileServer/ereefs/gbr1_2.0/daily-daily/EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-26.nc
# Downloading: EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-26.nc
# Saved to: downloads\EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-26.nc
#
# Download process completed.

# %%
# Download NOAA files

download_netcdf_noaa(
    base_url='https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/',
    download_dir=download_dir,
    start_year=2024, start_month=2, start_day=15,
    end_year=2024, end_month=2, end_day=10,
    file_prefix='ct5km_dhw_v3.1_',
    date_format='%Y%m%d'
)
# Out:
# ============================================================
# 🌀 NOAA NetCDF Downloader
# - Downloads NetCDF files from NOAA based on date patterns in filenames
# - Supports daily files organized by year
# - Checks for file existence using HTTP HEAD before downloading
# - Allows filename customization using prefix, suffix, and date format
# ============================================================
#
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230115.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230115.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230115.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230116.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230116.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230116.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230117.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230117.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230117.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230118.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230118.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230118.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230119.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230119.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230119.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230120.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230120.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230120.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230121.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230121.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230121.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230122.nc
# ⬇️  Downloading: ct5km_dhw_v3.1_20230122.nc
# ✅ Saved to: downloads\ct5km_dhw_v3.1_20230122.nc
# 🔍 Checking: https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/2023/ct5km_dhw_v3.1_20230123.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Download NOAA files
# ----> 3 download_netcdf_noaa(
#       4     base_url='https://www.star.nesdis.noaa.gov/pub/socd/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/dhw/',
#       5     download_dir=download_dir,
#       6     start_year=2023, start_month=1, start_day=15,
#       7     end_year=2023, end_month=2, end_day=10,
#       8     file_prefix='ct5km_dhw_v3.1_',
#       9     date_format='%Y%m%d'
#      10 )
#
# File ~\OneDrive\04_Processing\00_PythonScripts\MARS3888\function_downloads.py:173, in download_netcdf_noaa(base_url, download_dir, start_year, start_month, end_year, end_month, file_prefix, file_suffix, date_format, start_day, end_day, verbose)
#     170 date_str = current_date.strftime(date_format)
#     171 file_name = f"{file_prefix}{date_str}{file_suffix}"
# --> 173 year_str = current_date.strftime("%Y")
#     174 file_url = f"{base_url.rstrip('/')}/{year_str}/{file_name}"
#     175 file_path = os.path.join(download_dir, file_name)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\api.py:100, in head(url, **kwargs)
#      89 r"""Sends a HEAD request.
#      90
#      91 :param url: URL for the new :class:`Request` object.
#    (...)     96 :rtype: requests.Response
#      97 """
#      99 kwargs.setdefault("allow_redirects", False)
# --> 100 return request("head", url, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     793     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     794     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797         sock=sock,
#     798         cert_reqs=self.cert_reqs,
#     799         ssl_version=self.ssl_version,
#     800         ssl_minimum_version=self.ssl_minimum_version,
#     801         ssl_maximum_version=self.ssl_maximum_version,
#     802         ca_certs=self.ca_certs,
#     803         ca_cert_dir=self.ca_cert_dir,
#     804         ca_cert_data=self.ca_cert_data,
#     805         cert_file=self.cert_file,
#     806         key_file=self.key_file,
#     807         key_password=self.key_password,
#     808         server_hostname=server_hostname_rm_dot,
#     809         ssl_context=self.ssl_context,
#     810         tls_in_tls=tls_in_tls,
#     811         assert_hostname=self.assert_hostname,
#     812         assert_fingerprint=self.assert_fingerprint,
#     813     )
#     814     self.sock = sock_and_verified.socket
#     816 # If an error occurs during connection/handshake we may need to release
#     817 # our lock so another connection can probe the origin.
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     972     if is_ipaddress(normalized):
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#     989     if assert_fingerprint:
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\util\ssl_.py:483, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     479         context.load_cert_chain(certfile, keyfile, key_password)
#     481 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 483 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     484 return ssl_sock
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\util\ssl_.py:527, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     524     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     525     return SSLTransport(sock, ssl_context, server_hostname)
# --> 527 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1101             if timeout == 0.0:
#    1102                 # non-blocking
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#    1106     try:
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1380     if timeout == 0.0 and block:
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#    1384     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
# Download CAWCR-CSIRO files

download_netcdf_csiro(
    base_url="https://data-cbr.csiro.au/thredds/fileServer/catch_all/CMAR_CAWCR-Wave_archive/CAWCR_Wave_Hindcast_1979-2010/gridded/",
    download_dir=download_dir,
    start_year=2010,
    start_month=1,
    end_year=2010,
    end_month=2,
    file_prefix="ww3.aus_4m.",
    date_format="%Y%m"
)
# Out:
# ============================================================
# 🌀 CSIRO Wave Hindcast NetCDF Downloader
# - Downloads NetCDF files from CSIRO's Wave Hindcast archive
# - Checks for file existence using HTTP HEAD before download
# - Allows filename customization using prefix, suffix, and date format
# ============================================================
#
# 🔍 Checking: https://data-cbr.csiro.au/thredds/fileServer/catch_all/CMAR_CAWCR-Wave_archive/CAWCR_Wave_Hindcast_1979-2010/gridded/ww3.aus_4m.201001.nc
# ⬇️  Downloading: ww3.aus_4m.201001.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Download CAWCR-CSIRO files
# ----> 3 download_netcdf_csiro(
#       4     base_url="https://data-cbr.csiro.au/thredds/fileServer/catch_all/CMAR_CAWCR-Wave_archive/CAWCR_Wave_Hindcast_1979-2010/gridded/",
#       5     download_dir=download_dir,
#       6     start_year=2010,
#       7     start_month=1,
#       8     end_year=2010,
#       9     end_month=2,
#      10     file_prefix="ww3.aus_4m.",
#      11     date_format="%Y%m"
#      12 )
#
# File ~\OneDrive\04_Processing\00_PythonScripts\MARS3888\function_downloads.py:292, in download_netcdf_csiro(base_url, download_dir, start_year, start_month, end_year, end_month, file_prefix, file_suffix, date_format, start_day, end_day, verbose)
#     288     print()
#     290 os.makedirs(download_dir, exist_ok=True)
# --> 292 current_date = datetime(start_year, start_month, 1)
#     293 end_date = datetime(end_year, end_month, 1)
#     295 while current_date <= end_date:
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\response.py:1257, in HTTPResponse.stream(self, amt, decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
# -> 1257         data = self.read(amt=amt, decode_content=decode_content)
#    1259         if data:
#    1260             yield data
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)   1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\site-packages\urllib3\response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\anaconda3\envs\MARS3888\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# List NetCDF files
data_files = natsorted(glob.glob(os.path.join(download_dir, "*.nc")))

if not data_files:
    print("No NetCDF files found.")
else:
    print("\nAvailable NetCDF files:\n")

    for i, f in enumerate(data_files):
        print(f"[{i}] {os.path.basename(f)}")

    # Choose which file to open
    file_index = int(input("\nEnter the number of the file to open: "))
    selected_file = data_files[file_index]

    print(f"\nOpening: {selected_file}\n")

    ds = xr.open_dataset(selected_file)
    print(ds)
# Out:
# Available NetCDF files:
#
# [0] EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-25.nc
# [1] EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-26.nc
# [2] ct5km_dhw_v3.1_20230115.nc
# [3] ct5km_dhw_v3.1_20230116.nc
# [4] ct5km_dhw_v3.1_20230117.nc
# [5] ct5km_dhw_v3.1_20230118.nc
# [6] ct5km_dhw_v3.1_20230119.nc
# [7] ct5km_dhw_v3.1_20230120.nc
# [8] ct5km_dhw_v3.1_20230121.nc
# [9] ct5km_dhw_v3.1_20230122.nc
# Enter the number of the file to open:  0
# Opening: downloads\EREEFS_AIMS-CSIRO_gbr1_2.0_hydro_daily-daily-2017-08-25.nc
#
# <xarray.Dataset> Size: 4GB
# Dimensions:      (time: 1, latitude: 4237, longitude: 2671, k: 16)
# Coordinates:
#   * time         (time) datetime64[ns] 8B 2017-08-24T14:00:00
#   * latitude     (latitude) float64 34kB -28.59 -28.58 -28.58 ... -7.415 -7.41
#   * longitude    (longitude) float64 21kB 142.0 142.0 142.0 ... 155.4 155.4
#     zc           (k) float64 128B ...
# Dimensions without coordinates: k
# Data variables:
#     mean_wspeed  (time, latitude, longitude) float32 45MB ...
#     mean_cur     (time, k, latitude, longitude) float32 724MB ...
#     eta          (time, latitude, longitude) float32 45MB ...
#     salt         (time, k, latitude, longitude) float32 724MB ...
#     temp         (time, k, latitude, longitude) float32 724MB ...
#     wspeed_u     (time, latitude, longitude) float32 45MB ...
#     wspeed_v     (time, latitude, longitude) float32 45MB ...
#     u            (time, k, latitude, longitude) float32 724MB ...
#     v            (time, k, latitude, longitude) float32 724MB ...
# Attributes: (12/21)
#     Conventions:                   CF-1.0
#     Run_ID:                        2
#     _CoordSysBuilder:              ucar.nc2.dataset.conv.CF1Convention
#     aims_ncaggregate_buildDate:    2023-07-05T05:27:49+10:00
#     aims_ncaggregate_datasetId:    products__ncaggregate__ereefs__gbr1_2-0__d...
#     aims_ncaggregate_firstDate:    2017-08-25T00:00:00+10:00
#     ...                            ...
#     prefix_list_puv__:             https://w3id.org/env/puv#
#     prefix_list_qudt__:            http://qudt.org/vocab/unit/
#     shoc_version:                  v1.1 rev(5620)
#     technical_guide_link:          https://eatlas.org.au/pydio/public/aims-er...
#     technical_guide_publish_date:  2020-08-18
#     title:                         eReefs AIMS-CSIRO GBR1 Hydrodynamic v2.0 d...

# %% [markdown]
# # End
